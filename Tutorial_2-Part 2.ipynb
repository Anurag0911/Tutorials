# %% [markdown]
# # 2.1 Python Variables
#
# Variables are containers for storing data values.

# %%
Var = 20
var = 10
print(id(Var))
print(id(var))
# Out:
# 10

# %%
yy =

# %%
Var2 = 20
print(id(Var))
# Out:
# 94134326340704

# %% [markdown]
# # 2.2 Variable Names

# %%
var = 7
var = 3
_var = 4 

my_name = 4
print(var + _var)
# Out:
# 7

# %% [markdown]
# # 2.3 Many Values to Multiple Variables

# %%
x, y, z = 20, 30, 60
print(x)
print(y)
print(z)
# Out:
# 20
# 30
# 60

# %% [markdown]
# # 2.4 One Value to Multiple Variables

# %%
x=y=z = 20
print(x)
print(y)
print(z)
# Out:
# 20
# 20
# 20

# %% [markdown]
# # 2.5 How to get output from Variables

# %% [markdown]
# # 2.6 How to get Input Into the Variables

# %%
var = int(input("Enter Name:"))
print(type(var))
# Out:
# Enter Name:34
# <class 'int'>
