# %% [markdown]
# # 1. Data Structures

# %% [markdown]
# What is a Data structure?
#
# Ans: A data structure is a particular way of organizing data so that the data can be used effectively.
#
# So, We are getting into one of the most important topics in python for data science as any data science task involves storage and organization of data objects.
#
# 1. Tuple
# 2. List
# 3. Set
# 4. Dictionary

# %% [markdown]
# # 2. How Addressing Works

# %% [markdown]
# - Every variable in python is instance of an object.
#
#  - When a variable is assigned to a value then Python creates a new object to store the value.Thus a reference or pointer to an object is created. This pointer is then assigned to the variable and as a result, the variable becomes instance of the object. We can check it using type function.
#
# - For Example When we create a variable x = 5, python look into the memory if 5 is already available in RAM..
#
#  - if it is available then it reuses it and assign the id of existing 5 to the variable x.
#
#  - if not available it will create 5 and assign its unique object id to x.
#
#  - Then the variable x becomes instance of the object

# %%
x = 5
y = 5
print(id(x))
print(id(y))
# Out:
# 94825415813760
# 94825415813760

# %% [markdown]
# # 3. Immutable and Mutable Objects

# %% [markdown]
# - Objects whose value cannot be changed once created are called immutable Objects.
#  - Example :- Data types like int, float, bool, string, tuple.
#
# - An object whose value can be changed once created are called mutable Objects.
#  - Example :- list, dict, set .

# %% [markdown]
# # 4. Tuples

# %% [markdown]
# Tuples are immutable ordered sequences, typically used to store collections of heterogeneous data.
#
# Let us understand tuples using some examples.

# %% [markdown]
# ## 4.1 Creating Tuples</h4>

# %%
#Create an Empty Tuple
# () is used to create a tuple
myTuple = ()
print(myTuple)
type(myTuple)
# Out:
# ()
# tuple

# %%
#Using tuple() constructor to make a tuple.
mytuple = tuple(("red", "blue", "green")) # note the double round-brackets
print(mytuple)
# Out:
# ('red', 'blue', 'green')

# %%
# Creating Hetrogeneous tuple(different data types)
myTuple = ("amino",10.2,20,[1,2,3])

print(myTuple)
print(type(myTuple))

# Print the type of value on each index
print(type(myTuple[0]))
print(type(myTuple[1]))
print(type(myTuple[2]))
print(type(myTuple[3]))
# Out:
# ('amino', 10.2, 20, [1, 2, 3])
# <class 'tuple'>
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'list'>

# %%
#To create tuple with only one item, remember to add commma.
myTuple = ("amino",)
print(type(myTuple))

#NOT a tuple
thistuple = ("amino")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# ## 4.2 Indexing and Slicing

# %% [markdown]
# As tuples are ordered sequence each element of a tuple can be accessed using an index. Each element can be obtained by the name of the tuple followed by a square bracket with the index number

# %%
myTuple = ("amino",10.2,20,[1,2,3])
print(myTuple[2])
print(myTuple[-3])
# Out:
# 20
# 10.2

# %%
# Print element on each index
print("Element 1 of Tuple at Index 0: ", myTuple[0])
print("Element 2 of Tuple at Index 1: ", myTuple[1])
print("Element 3 of Tuple at Index 2: ", myTuple[2])
print("Element 4 of Tuple at Index 3: ", myTuple[3])
# Out:
# Element 1 of Tuple at Index 0:  amino
# Element 2 of Tuple at Index 1:  10.2
# Element 3 of Tuple at Index 2:  20
# Element 4 of Tuple at Index 3:  [1, 2, 3]

# %% [markdown]
# ## 4.3 Nested Tuple

# %% [markdown]
# A tuple can contain another tuple as well as other more complex data types. This process is called 'nesting'. Consider the following tuple with several elements:

# %%
# Create a nested tuple
nt =(10, 20, ("Amino", "Coder") ,(30,(40,50)))

# %%
# Print element on any Index
print("Element 1 of Tuple: ", nt[0])
print("Element 2 of Tuple: ", nt[1])
# Print element on any Nested index
print("Element 1 of Element 4 of Tuple: ", nt[3][0])
# Out:
# Element 1 of Tuple:  10
# Element 2 of Tuple:  20
# Element 1 of Element 4 of Tuple:  30

# %% [markdown]
# ## 4.4 Slicing

# %% [markdown]
# We can slice tuples, obtaining new tuples with the corresponding elements:

# %%
myTuple = ("movie",10.2,20,[1,2,3] )
# Slice from index 0 to index 2
myTuple[0:3:2]
# Out:
# ('movie', 20)

# %%
# Slice from index 0 to index 2
myTuple[0:3]
# Out:
# ('movie', 10.2, 20)

# %%
print(myTuple[:2])      #if we dont enter Start number, it defaults to 0
print(myTuple[3:])      # if we dont enter end number, it defaults to end the tuple
# Out:
# ('movie', 10.2)
# ([1, 2, 3],)

# %% [markdown]
# ## 4.5 Tuple immutablility

# %% [markdown]
# Tuples are immutable as strings.
#
# This means that elements of a tuple cannot be changed once created.
#
# However, item of mutable element like list can be changed.
#
# Let us understand this with examples

# %%
myTuple = (10, 12.5, "Amino") #Tuple with diff data type values
myTuple
# Out:
# (10, 12.5, 'Amino')

# %%
myTuple[0] = 20 # trying to change the int value 10 at index 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-5ff789a37f60> in <module>()
# ----> 1 myTuple[0] = 20 # trying to change the int value 10 at index 0
#
# TypeError: 'tuple' object does not support item assignment

# %%
myTuple[1] = "python" # trying to change the float value 12.5 at index 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8b03e6598f62> in <module>()
# ----> 1 myTuple[1] = "python" # trying to change the float value 12.5 at index 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
myTuple[2] = "python" # trying to change the string value data at index 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-3b20d3442e7e> in <module>()
# ----> 1 myTuple[2] = "python" # trying to change the string value data at index 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
myTuple
# Out:
# (10, 12.5, 'Amino')

# %%
#We cannot add items to a tuple:
myTuple = ("apple", "banana", "cherry")
myTuple[3] = "orange" # This will raise an error
print(myTuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ce19b4e3d7b0> in <module>()
#       1 #We cannot add items to a tuple:
#       2 myTuple = ("apple", "banana", "cherry")
# ----> 3 myTuple[3] = "orange" # This will raise an error
#       4 print(myTuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#We cannot remove items in a tuple.The del keyword can delete the tuple completely:
myTuple = ("apple", "banana", "cherry")
del myTuple
print(myTuple) #this will raise an error because the tuple no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6f9cb8878dad> in <module>()
#       2 myTuple = ("apple", "banana", "cherry")
#       3 del myTuple
# ----> 4 print(myTuple) #this will raise an error because the tuple no longer exists
#
# NameError: name 'myTuple' is not defined

# %% [markdown]
# ## 4.6 Tuple Methods

# %% [markdown]
# Python has two built-in methods that you can use on tuples.

# %%
myTuple = (20, 50, (10, 20), [10, 50], 10)

# %%
#count()	Returns the number of times a specified value occurs in a tuple
myTuple.count(10)
# Out:
# 1

# %%
#index()	Searches the tuple for a specified value and returns the index of where it first occurs
myTuple.index(10)
# Out:
# 4

# %% [markdown]
# <h4 id="mutableimutable">Tuple Packing and Unpacking</h4>

# %% [markdown]
# - In packing, we place element values into a new tuple.
#
# - In unpacking we extract and assign element values back into variables.

# %%
x = ("Amino", 10000, "Coder")    # tuple packing
(var1, var2 , var3) = x    # tuple unpacking
print(var1)
print(var2)
print(var3)
# Out:
# Amino
# 10000
# Coder

# %% [markdown]
# <h4 id="mutableimutable">Sorting</h4>

# %%
# A sample tuple
values = (0, 9, 6, 5, 10, 8, 9, 6, 2)
print(values)
type(values)
# Out:
# (0, 9, 6, 5, 10, 8, 9, 6, 2)
# tuple

# %% [markdown]
# We can sort the values in a tuple and save it to a new variable:

# %%
valueSorted = sorted(values)
print(values)
print(valueSorted)
print(type(valueSorted))
# Out:
# (0, 9, 6, 5, 10, 8, 9, 6, 2)
# [0, 2, 5, 6, 6, 8, 9, 9, 10]
# <class 'list'>

# %%
# Sort the tuple in Descending Order
valueSorted = sorted(values, reverse = True)
valueSorted
# Out:
# [10, 9, 9, 8, 6, 6, 5, 2, 0]

# %% [markdown]
# <h1>Thank you</h1>
