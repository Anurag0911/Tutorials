# %% [markdown]
# # Welcome to the Python for Beginners course

# %% [markdown]
# ## 1.1 Introduction
#
# General Purpose Language
#
# It is used for:
#
# 1. Web development.
# 2. Software development.
# 3. System scripting.
#
# www.python.org

# %%
Name = input("Enter you name:")
print("Hi! How are you " + Name)
# Out:
# Enter you name:amino
# Hi! How are you amino

# %% [markdown]
# ## 1.2 Input/Output Statement or IO Statement

# %% [markdown]
# Output statements

# %%
print("hello world")
# Out:
# hello world

# %%
print("i love Python")
# Out:
# i love Python

# %%
print('i','love','python',sep="")
# Out:
# ilovepython

# %%
print("Amino",end = "      ")
print("Amino")
print("Amino")
# Out:
# Amino      Amino
# Amino

# %% [markdown]
# Input statements

# %%
input("Enter the name:")
# Out:
# Enter the name:Amino
# 'Amino'

# %%
type(int(input("Enter the year:")))
# Out:
# Enter the year:20
# int
